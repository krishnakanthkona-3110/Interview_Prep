# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnakanthkona-3110/Interview_Prep/blob/main/Interview_Focused/Managerial_Round_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How Do You Handle Pressure?
#
# Don't say:
#
# "I work very well under pressure."
#
# Instead give a process.
#
# "When there is pressure, I first prioritize tasks based on business impact and urgency. For a production issue, for example, my first priority is restoring the service or minimizing the impact. Then I investigate the root cause. I also communicate the status clearly to the stakeholders rather than waiting until the issue is completely resolved.
#
# Once the immediate issue is handled, I focus on the root-cause fix and preventive measures."
#
# That's a manager-level answer.

# %% [markdown]
# # What If You Disagree With Your Manager?
#
# Very common.
#
# "First, I would try to understand the reasoning behind the decision. If I have a different technical opinion, I would present it with supporting data or technical reasoning rather than making it personal.
#
# If the final decision is still different from my recommendation, I would align with the decision and focus on executing it effectively, unless there is a significant technical or security risk that needs to be escalated."
#
# Excellent managerial-round answer.

# %% [markdown]
# # "How Do You Handle a Mistake?"
#
# Never say:
#
# "I don't make mistakes."
#
# Say:
#
# "If I make a mistake, my first priority is to understand the impact and communicate it appropriately. I would take ownership, fix the immediate problem, identify the root cause and then put a preventive measure in place, such as validation, monitoring or an additional test case.
#
# I believe the important thing is not hiding a mistake but making sure the same issue doesn't happen again."

# %% [markdown]
# # How Do You Prioritize Multiple Tasks?
#
# Use:
#
# Impact + Urgency + Dependency + Effort
#
# "I prioritize based on business impact and urgency first. Production issues and customer-impacting problems take priority. Then I consider dependencies—if one task is blocking multiple team members, I prioritize that accordingly. For normal development work, I consider deadlines and effort and communicate if priorities conflict."

# %% [markdown]
# # "What Is Your Biggest Strength?"

# %% [markdown]
# # "What Is Your Weakness?"
#
# Avoid:
#
# ❌ "I'm a perfectionist."
#
# ❌ "I work too hard."
#
# Instead:
#
# "Earlier, I sometimes spent more time than necessary trying to solve a problem independently before asking for help. I've been improving this by time-boxing my investigation. If I don't make meaningful progress within a reasonable time, I communicate the problem, share what I've already investigated and ask for input."
#
# This sounds genuine and shows improvement.

# %% [markdown]
# # Why Should We Hire You?

# %% [markdown]
# # What If You Don't Know Something?"
#
# Say:
#
# "If I don't know something, I won't try to guess or give an incorrect answer. I'll first clarify the requirement, then break the problem down into what I know and what I need to investigate. I usually use documentation, experimentation and discussion with experienced team members to close the gap quickly."
#
# Managers generally like this attitude.

# %% [markdown]
# # Questions to Ask the Manager
#
# At the end they may ask:
#
# "Do you have any questions for me?"
#
# Don't say:
#
# "No."
#
# Ask 1–2 good questions.
#
# Question 1
#
# # "What would you expect from someone in this role during the first three to six months?"
#
# Question 2
#
# #"What are the major AI/ML problems the team is currently trying to solve?"
#
# Question 3
#
# # "How is the team structured, and how do AI/ML engineers collaborate with the product and engineering teams?"
#
# Question 4
#
# # "How do you measure success for this role?"
#
# These make you sound interested in the work, not just the salary.
