# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnakanthkona-3110/Interview_Prep/blob/main/Memory_Agent_Patterns_CoT_ReAct_Reflection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # What is a Checkpointer in LangGraph?
#
# A checkpointer is a state persistence mechanism used by LangGraph to:
#
# Save the current state of a graph
#
# Store memory across nodes
#
# Allow resuming execution after failure
#
# Maintain conversation continuity across requests
#
# In short:
#
# LangGraph Checkpointer = Memory + Recovery + Continuity for your AI workflow
#
# Without a checkpointer, your graph forgets everything after execution.

# %% [markdown]
# # LLMs don't have any intrinsic memory

# %% [markdown]
# # Memory :-
# It is the information stored somewhere outside the live prompt, that has to be retrieved before it can be used...
#
#
# AI Agent Memory is the ability of an AI agent to store, recall and use information from past interactions to make better decisions in the present and future. Without memory, an agent treats every interaction as if it is the first interaction. With memory, an agent can maintain context, adapt to users and improve over time i.e memory gives AI agent continuity, context-awareness and learning abilities.

# %% [markdown]
# Need of Memory by AI Agents:
# Many real-world scenarios demand agents to remember and adapt to:
#
#
# ---
#
# Keep track of conversations.
#
# Track progress in multi-step workflows.
#
# Learn from past feedback and improve.
#
# To keep the personalization i.e remembering user preferences.
#
# An agent without memory is limited to short and isolated responses whereas it can act more intelligently and deliver better experience with memory.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Now, let me summarize what we have covered. Working memory in the context window handles active reasoning. While long term stores handle persistence and scale. Episode memory captures specific events, smarting memory capture facts and relationships, procedural memory captures learn skill and workflows and effective retrieval. Combines vector search met filtering and re-ranking to surface the right memories at the right time for implementation priorities, start with the conversation history, persistence, and basic semantic retrieval before building sophisticated and memory types. Add user fact extraction and preference learning. Once basic retrieval works reliably in production, then add implementation consolidation, forgetting mechanisms only after you have enough data to understand your actual memory patterns. These techniques form the foundation for building agents that generally learn and improve over time for more implementation and code examples.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # For Interviews
#
# ---
# Memory - It is the information stored somewhere outside the live prompt, that has to be retrieved before it can be used...
#
#
#
#
# *   LLMs don't have any intrinsic memory.
#
# ---
