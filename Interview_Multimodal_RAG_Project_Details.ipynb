# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnakanthkona-3110/Interview_Prep/blob/main/Interview_Multimodal_RAG_Project_Details.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# (Nvidia) Nemo Guardrails - Drawback - If none of the scenarios, then it will bypass our guardrails
#
# - It will check similarity (not the LLM, fastembeddings will check)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
